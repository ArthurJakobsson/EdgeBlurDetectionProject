# %% [markdown]
# # Computer Science Final Project Camera Testing
#
# ... current status...
#
# Relevant tutorials:
#     Detecting a primary non-Gausian blur
#  - https://www.pyimagesearch.com/2015/09/07/blur-detection-with-opencv/
#  - Similar OpenCV photo analysis project done for Robotics
#  - http://104.248.180.137:5000/notebooks/2019%20Camera%20Stitching/Testing.ipynb
#  - http://104.248.180.137:5000/tree
#  - http://104.248.180.137:5000/notebooks/2019%20Camera%20Stitching/4board-setup/Chessboard%20detection-withpoints.ipynb
#  - https://www.learnopencv.com/histogram-of-oriented-gradients/
#
# Detecting a Gaussian blur mechanism
# - http://www.cse.cuhk.edu.hk/leojia/all_final_papers/blur_detect_cvpr08.pdf
#
# To run
# - Have pip installed
# - Have jupyter installed
# - Run "jupyter notebook" in terminal

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from imutils import paths
import argparse


def show(img):
    plt.axis('off')
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('img/BlurrBack.jpg')
height, width, channels = img.shape
print (height, width, channels)
show(img)
# Out:
# 1532 1149 3

# %%
cv2.Laplacian(img, cv2.CV_64F).var()
# Out:
# 89.83031068533376
